# %% [markdown]
# # Deep Network

# %%
from tensorflow import keras
import constants
import util
import numpy

[x_prove, y_prove] = util.read(constants.PROVE)
[x_train, y_train] = util.read(constants.TRAIN)
[x_test, y_test] = util.read(constants.TEST)

# %%
model = keras.models.load_model('deep_model_v2.h5')

# %%
model.evaluate(x_train.values, numpy.asarray(y_train))
# Out:
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================ ...
# [0.38152300574806297, 0.8216292]

# %%
model.evaluate(x_test.values, numpy.asarray(y_test))
# Out:
# 89/1 [==============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 68us/sample - loss: 0.4255 - accuracy: 0.8539
# [0.611689022082961, 0.85393256]

# %%
model.evaluate(x_prove.values, numpy.asarray(y_prove))
# Out:
# 90/1 [============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 106us/sample - loss: 0.6664 - accuracy: 0.8111
# [0.5375451405843099, 0.8111111]
